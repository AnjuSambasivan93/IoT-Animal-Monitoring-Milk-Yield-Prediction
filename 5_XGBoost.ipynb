# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv('editedab.csv',index_col=0)

# %%
dataset.head()
# Out:
#            DATE  TMR  GRASS  WATER  BATH  MILK
# COWid
# cow01  01-01-19  6.8   17.6   28.6     3  18.0
# cow01  02-01-19  5.6   13.9   15.3     2  16.8
# cow01  03-01-19  7.1   17.9   24.2     1  14.5
# cow01  04-01-19  6.6   14.5   22.3     0  14.3
# cow01  05-01-19  7.4   17.3   29.0     3  17.6

# %%
dataset.describe()
# Out:
#               TMR       GRASS       WATER        BATH        MILK
# count  240.000000  240.000000  240.000000  240.000000  240.000000
# mean     6.486250   15.795833   23.039167    1.833333   17.907083
# std      0.610661    1.567659    4.069466    0.890050    2.276934
# min      5.500000   13.000000   15.100000    0.000000   14.000000
# 25%      5.900000   14.400000   20.000000    1.000000   15.875000
# 50%      6.500000   15.900000   23.200000    2.000000   18.000000
# 75%      7.000000   17.100000   26.200000    3.000000   20.100000
# max      8.600000   18.400000   30.000000    3.000000   22.000000

# %%
dataset.describe()
# Out:
#               TMR       GRASS       WATER        BATH        MILK
# count  240.000000  240.000000  240.000000  240.000000  240.000000
# mean     6.486250   15.795833   23.039167    1.833333   17.907083
# std      0.610661    1.567659    4.069466    0.890050    2.276934
# min      5.500000   13.000000   15.100000    0.000000   14.000000
# 25%      5.900000   14.400000   20.000000    1.000000   15.875000
# 50%      6.500000   15.900000   23.200000    2.000000   18.000000
# 75%      7.000000   17.100000   26.200000    3.000000   20.100000
# max      8.600000   18.400000   30.000000    3.000000   22.000000

# %%
X = dataset.iloc[:,1:5].values
y = dataset.iloc[:,len( dataset.iloc[0])-1].values

# %%
print(X)
print('\n')
print(y)
# Out:
# [[ 6.8 17.6 28.6  3. ]
#  [ 5.6 13.9 15.3  2. ]
#  [ 7.1 17.9 24.2  1. ]
#  [ 6.6 14.5 22.3  0. ]
#  [ 7.4 17.3 29.   3. ]
#  [ 6.1 17.3 20.4  2. ]
#  [ 5.7 17.6 28.6  0. ]
#  [ 7.3 16.1 21.1  0. ]
#  [ 7.  14.1 21.1  3. ]
#  [ 5.6 13.7 22.9  3. ]
#  [ 6.7 14.1 21.4  1. ]
#  [ 7.1 13.8 24.   1. ]
#  [ 6.1 17.1 23.8  1. ]
#  [ 6.7 18.1 29.1  3. ]
#  [ 6.9 14.2 24.1  0. ]
#  [ 7.3 18.  25.4  1. ]
#  [ 7.1 15.8 29.5  1. ]
#  [ 5.8 18.4 25.   0. ]
#  [ 7.3 18.4 22.2  2. ]
#  [ 6.1 17.  27.2  3. ]
#  [ 5.7 17.7 21.4  2. ]
#  [ 6.4 15.9 29.1  0. ]
#  [ 6.1 13.  23.6  3. ]
#  [ 6.3 18.4 16.4  1. ]
#  [ 5.9 17.9 19.7  2. ]
#  [ 7.1 16.9 15.1  2. ]
#  [ 6.8 14.5 27.1  3. ]
#  [ 5.9 15.1 23.4  1. ]
#  [ 6.2 17.3 20.9  1. ]
#  [ 5.6 13.3 29.   0. ]
#  [ 7.4 15.6 23.4  3. ]
#  [ 5.8 13.1 27.9  2. ]
#  [ 6.8 15.2 21.2  0. ]
#  [ 5.9 16.3 18.1  1. ]
#  [ 6.2 15.6 20.4  1. ]
#  [ 6.7 16.5 15.9  0. ]
#  [ 6.8 18.3 27.6  3. ]
#  [ 6.3 14.8 21.5  1. ]
#  [ 6.9 13.7 21.7  1. ]
#  [ 6.6 17.3 15.3  2. ]
#  [ 6.6 15.  16.8  1. ]
#  [ 6.6 15.6 19.7  0. ]
#  [ 5.6 17.1 19.5  0. ]
#  [ 7.  16.1 25.   1. ]
#  [ 6.2 13.6 26.2  1. ]
#  [ 6.  15.6 29.5  0. ]
#  [ 6.4 14.3 27.6  3. ]
#  [ 5.8 13.7 19.1  1. ]
#  [ 5.9 16.  24.3  2. ]
#  [ 5.9 16.1 26.4  1. ]
#  [ 5.6 14.8 28.7  1. ]
#  [ 6.3 18.3 22.4  1. ]
#  [ 7.4 14.4 19.   1. ]
#  [ 7.3 14.1 26.3  1. ]
#  [ 6.  13.8 25.5  2. ]
#  [ 7.1 15.2 15.8  2. ]
#  [ 6.2 14.2 21.8  2. ]
#  [ 6.8 17.4 16.7  2. ]
#  [ 5.8 16.1 26.9  2. ]
#  [ 5.9 16.8 20.4  2. ]
#  [ 6.5 13.2 15.8  3. ]
#  [ 6.9 14.4 15.8  3. ]
#  [ 6.2 16.5 26.4  2. ]
#  [ 6.9 17.9 22.5  1. ]
#  [ 7.2 18.1 29.6  2. ]
#  [ 5.5 15.7 23.8  2. ]
#  [ 6.3 14.3 28.2  1. ]
#  [ 6.3 17.  21.5  2. ]
#  [ 6.9 17.9 24.9  1. ]
#  [ 6.1 16.8 29.7  1. ]
#  [ 6.1 14.1 20.7  1. ]
#  [ 7.4 16.6 26.8  1. ]
#  [ 6.1 16.7 19.4  3. ]
#  [ 6.  17.6 15.6  2. ]
#  [ 5.8 16.4 24.3  2. ]
#  [ 7.  17.3 23.7  3. ]
#  [ 5.6 14.5 24.8  2. ]
#  [ 7.4 14.7 17.3  1. ]
#  [ 6.2 13.4 30.   2. ]
#  [ 5.9 14.4 23.2  3. ]
#  [ 6.5 13.2 29.   2. ]
#  [ 7.5 15.6 25.4  1. ]
#  [ 7.4 14.2 25.8  1. ]
#  [ 5.7 13.  24.8  2. ]
#  [ 7.4 16.9 19.2  2. ]
#  [ 7.5 18.4 19.1  2. ]
#  [ 5.7 16.3 25.3  3. ]
#  [ 5.5 16.4 17.2  2. ]
#  [ 6.3 13.1 26.2  3. ]
#  [ 5.8 16.9 29.7  2. ]
#  [ 6.4 16.3 28.5  2. ]
#  [ 6.1 17.6 16.1  3. ]
#  [ 7.3 14.6 26.6  1. ]
#  [ 5.9 15.  25.9  1. ]
#  [ 6.  17.1 23.2  1. ]
#  [ 7.  16.2 22.3  2. ]
#  [ 7.3 17.  26.2  3. ]
#  [ 7.5 17.6 15.3  1. ]
#  [ 7.3 14.7 18.7  1. ]
#  [ 7.1 14.7 28.   1. ]
#  [ 7.2 13.9 25.7  3. ]
#  [ 5.7 14.9 22.   1. ]
#  [ 6.5 17.1 19.2  2. ]
#  [ 6.3 14.1 21.3  3. ]
#  [ 5.7 13.8 22.3  0. ]
#  [ 5.5 16.5 21.8  2. ]
#  [ 7.1 17.3 22.1  1. ]
#  [ 5.9 14.4 20.   2. ]
#  [ 7.  18.  25.6  1. ]
#  [ 7.  15.1 26.2  1. ]
#  [ 6.5 14.4 26.7  1. ]
#  [ 7.1 17.5 25.5  2. ]
#  [ 6.5 13.3 23.2  2. ]
#  [ 5.6 17.6 28.9  1. ]
#  [ 6.2 14.1 20.2  2. ]
#  [ 6.8 16.6 25.9  3. ]
#  [ 6.4 17.4 29.3  2. ]
#  [ 6.5 15.9 18.3  2. ]
#  [ 6.7 17.  20.   2. ]
#  [ 6.5 18.  15.2  3. ]
#  [ 8.6 18.2 28.1  3. ]
#  [ 6.6 16.7 23.6  2. ]
#  [ 7.4 14.9 17.1  3. ]
#  [ 7.1 13.1 26.4  3. ]
#  [ 5.9 16.2 21.7  3. ]
#  [ 5.8 13.1 26.5  3. ]
#  [ 6.1 13.2 27.9  2. ]
#  [ 7.  17.1 15.5  2. ]
#  [ 5.8 14.2 24.3  3. ]
#  [ 6.3 15.8 20.5  2. ]
#  [ 7.2 13.8 16.7  1. ]
#  [ 6.8 16.4 22.3  2. ]
#  [ 5.6 13.3 20.   1. ]
#  [ 7.5 14.5 27.2  3. ]
#  [ 7.  15.  27.4  1. ]
#  [ 7.2 13.3 22.7  2. ]
#  [ 6.7 17.9 22.2  3. ]
#  [ 7.1 15.8 21.6  2. ]
#  [ 7.2 16.3 27.3  2. ]
#  [ 7.5 17.4 22.9  1. ]
#  [ 5.6 14.2 22.5  0. ]
#  [ 6.3 16.6 22.3  3. ]
#  [ 5.7 14.  19.   2. ]
#  [ 6.9 15.5 27.8  3. ]
#  [ 7.  16.7 25.4  2. ]
#  [ 6.6 13.5 26.3  0. ]
#  [ 5.6 14.1 29.8  3. ]
#  [ 6.6 14.5 23.   3. ]
#  [ 5.8 15.3 24.2  2. ]
#  [ 6.5 13.6 23.9  3. ]
#  [ 7.4 16.2 15.5  1. ]
#  [ 5.6 15.1 23.2  2. ]
#  [ 6.6 15.3 15.2  3. ]
#  [ 6.6 17.1 16.9  1. ]
#  [ 6.5 18.2 20.3  2. ]
#  [ 7.1 16.3 18.2  2. ]
#  [ 6.3 17.8 21.4  2. ]
#  [ 5.9 16.6 23.3  3. ]
#  [ 6.1 13.4 26.1  1. ]
#  [ 6.2 15.3 23.3  2. ]
#  [ 5.8 13.7 16.6  2. ]
#  [ 6.7 14.7 21.9  2. ]
#  [ 6.5 16.9 23.1  1. ]
#  [ 5.8 18.  17.1  2. ]
#  [ 6.2 17.9 28.1  3. ]
#  [ 5.6 15.  17.7  2. ]
#  [ 7.1 15.3 15.7  1. ]
#  [ 6.6 18.1 25.9  3. ]
#  [ 7.5 15.  17.3  1. ]
#  [ 7.  18.4 18.2  2. ]
#  [ 6.3 16.2 29.7  2. ]
#  [ 6.8 17.8 21.7  3. ]
#  [ 7.3 16.4 22.1  3. ]
#  [ 7.1 14.2 22.6  2. ]
#  [ 7.4 15.4 23.7  2. ]
#  [ 7.2 16.7 19.   1. ]
#  [ 6.  17.  23.3  3. ]
#  [ 5.7 17.8 16.9  2. ]
#  [ 5.9 16.4 23.8  2. ]
#  [ 7.1 13.9 25.   2. ]
#  [ 5.7 14.5 23.8  1. ]
#  [ 5.9 14.7 21.2  1. ]
#  [ 7.  15.3 18.5  2. ]
#  [ 5.8 17.6 26.1  2. ]
#  [ 5.7 14.8 19.8  3. ]
#  [ 7.3 17.8 19.9  0. ]
#  [ 7.3 18.2 28.6  1. ]
#  [ 7.3 16.1 29.3  2. ]
#  [ 6.6 14.8 20.3  1. ]
#  [ 7.1 15.5 25.8  2. ]
#  [ 5.9 18.2 22.5  2. ]
#  [ 6.7 13.6 27.1  1. ]
#  [ 7.1 17.6 29.9  3. ]
#  [ 7.  16.4 19.7  1. ]
#  [ 7.  17.9 24.3  3. ]
#  [ 6.9 18.  18.2  1. ]
#  [ 6.  14.1 22.8  1. ]
#  [ 6.7 17.2 23.3  2. ]
#  [ 6.1 15.1 29.2  2. ]
#  [ 6.9 14.1 23.2  3. ]
#  [ 5.6 13.4 26.5  2. ]
#  [ 6.1 14.  21.6  2. ]
#  [ 5.9 14.6 23.5  3. ]
#  [ 6.7 13.6 24.2  1. ]
#  [ 5.6 16.6 18.4  1. ]
#  [ 7.4 14.2 25.   2. ]
#  [ 5.8 16.  21.5  2. ]
#  [ 5.9 17.8 29.2  2. ]
#  [ 6.1 13.7 16.4  2. ]
#  [ 5.5 16.4 22.7  3. ]
#  [ 6.8 15.5 17.4  3. ]
#  [ 7.3 14.7 16.9  2. ]
#  [ 6.9 14.3 29.1  3. ]
#  [ 5.9 15.4 24.3  2. ]
#  [ 6.2 18.3 16.2  2. ]
#  [ 5.6 16.9 21.3  2. ]
#  [ 5.7 15.3 22.4  3. ]
#  [ 6.8 14.4 29.8  3. ]
#  [ 6.5 13.5 18.3  2. ]
#  [ 6.8 16.6 20.6  2. ]
#  [ 6.1 17.6 22.8  2. ]
#  [ 7.3 18.4 25.8  3. ]
#  [ 6.5 14.7 26.5  1. ]
#  [ 5.6 18.3 19.   0. ]
#  [ 5.7 16.4 24.   2. ]
#  [ 7.3 15.1 21.3  3. ]
#  [ 6.  16.3 19.1  2. ]
#  [ 7.2 16.9 24.2  3. ]
#  [ 6.  16.1 28.6  2. ]
#  [ 6.6 15.6 25.8  1. ]
#  [ 5.8 14.1 21.6  1. ]
#  [ 5.8 17.4 29.   2. ]
#  [ 6.4 17.6 19.1  3. ]
#  [ 7.2 16.  28.2  3. ]
#  [ 6.9 15.9 25.4  2. ]
#  [ 6.1 16.5 29.5  2. ]
#  [ 5.7 14.1 22.6  3. ]
#  [ 7.  15.2 26.8  2. ]
#  [ 6.8 17.9 26.   3. ]
#  [ 6.4 15.2 29.   2. ]]
#
#
# [18.  16.8 14.5 14.3 17.6 16.3 14.  14.3 16.5 17.3 15.8 14.2 15.5 17.5
#  14.1 14.6 14.4 14.3 17.  18.  16.2 14.2 17.5 14.5 15.9 15.9 17.8 14.2
#  15.8 14.  17.3 16.  14.8 16.3 16.8 16.5 17.9 15.  15.8 16.9 17.  14.9
#  17.  16.7 14.5 16.4 17.3 14.2 15.5 14.9 15.6 14.6 14.7 15.3 17.3 16.2
#  16.9 16.6 16.2 15.4 17.4 17.3 16.6 15.  15.6 16.3 15.3 16.9 15.3 15.7
#  15.1 15.1 17.2 14.5 15.6 17.2 15.5 14.4 15.  17.7 16.  15.  14.3 16.2
#  15.7 15.5 16.9 16.9 17.5 14.8 15.2 17.1 14.4 15.7 16.1 16.5 17.1 16.5
#  16.4 15.3 17.4 15.4 16.4 17.  14.6 16.9 15.5 15.2 15.6 15.7 14.8 15.8
#  16.1 16.1 14.7 17.1 16.8 16.9 14.8 16.7 22.  18.9 19.9 19.3 20.7 20.7
#  19.8 19.7 21.3 20.1 18.5 19.2 18.6 21.3 18.9 21.1 21.4 20.  21.  18.1
#  18.2 21.2 19.3 21.4 20.3 18.  21.1 21.1 18.7 21.3 18.4 20.6 21.2 18.9
#  19.  19.  20.6 20.7 18.3 20.1 20.3 20.8 18.6 20.2 20.4 18.9 19.  20.8
#  20.1 18.9 20.6 20.7 20.8 19.5 21.1 18.1 21.  20.4 20.3 20.6 18.7 19.7
#  20.1 20.2 20.8 18.3 18.8 20.2 18.  20.9 19.  18.9 21.5 18.9 21.  18.4
#  18.6 20.7 19.8 21.1 19.5 20.  21.  18.2 18.8 20.  19.1 18.1 19.9 20.5
#  21.1 18.8 21.4 20.9 19.5 19.9 21.4 21.  20.5 19.1 20.7 20.4 18.8 18.1
#  20.2 20.7 19.6 21.  20.4 18.5 18.  18.4 20.9 21.4 18.2 20.  20.1 20.2
#  21.5 20.5]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
a=X_train.shape
print(a)
b=X_test.shape
print(b)
c=y_train.shape
print(c)
d=y_test.shape
print(c)
# Out:
# (192, 4)
# (48, 4)
# (192,)
# (192,)

# %%
from xgboost import XGBRegressor
model = XGBRegressor( learning_rate=.5,max_depth=1)
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.5, max_delta_step=0,
#        max_depth=1, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
#help(XGBRegressor)

# %%
y_pred=model.predict(X_test)

# %%
diff=y_test-y_pred
print(diff)
plt.plot(diff)
plt.show()
# Out:
# [-1.49961548 -1.32198181 -1.45979691 -3.0244545  -1.06474724  1.68345833
#   2.51246605  2.29620285  2.8565876   1.74931335 -3.44856644  1.86906624
#  -1.79700546  1.14076347 -0.4127739   1.78109589  1.05466728 -2.36571045
#   2.17424812 -2.42118073 -2.48299751  2.47558556 -3.48275681 -0.06021843
#  -1.58452148 -0.67937279  1.65954361  1.32888794 -0.52392006  2.20719147
#  -2.47037392 -1.96745872  2.24659042  2.13936729  1.92062645 -3.55946655
#   1.97099686  2.53039322 -3.27940025 -2.85166321  0.91246605  1.01600494
#   0.39883575 -1.12504196 -1.39581299 -2.40183678 -1.42931213 -1.87905045]

# %%
df=pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})  
df 
df1=df.head(25)

# %%
from sklearn import metrics  
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test,y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1.8731957435607913
# Mean Squared Error: 4.19545639703579
# Root Mean Squared Error: 2.0482813276100016

# %%
y_pred1 = model.predict([[6.8,17.6,28.6,3]])
print(y_pred1)
# Out:
# [18.874086]

# %%
# Report the score of the prediction using the testing set
# It is simply the ratio of correct predictions divided by the total data points. 
accuracy = model.score(X_test,y_test)
print(accuracy*100,'%')
# Out:
# 31.097894239889868 %

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.3109789423988987

# %%
df1.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
